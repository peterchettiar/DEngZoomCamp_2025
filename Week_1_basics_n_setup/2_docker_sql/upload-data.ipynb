# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_parquet("yellow_tripdata_2023-01.parquet")
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
# initialising an engine object and passing "{type of database}://{user}:{password}@localhost(port}/{database_name}" as argument

engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

# %%
engine.connect()

# %%
# generating DDL statement

print(pd.io.sql.get_schema(df, "yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
# next lets create and insert this table into our database

df.to_sql(name="yellow_taxi_data", con=engine, if_exists='replace')
# Out:
# 766

# %%
# now to check if the table was uploaded

query_schema = """
SELECT * 
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog'
AND schemaname != 'information_schema'
"""

pd.read_sql(query_schema, con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
# lastly to test to see if we can query

query_table = """
SELECT * FROM yellow_taxi_data LIMIT 100
"""

pd.read_sql(query_table, con=engine)
# Out:
#     index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       0         2  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1       1         2  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2       2         2  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3       3         1  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4       4         2  2023-01-01 00:10:29   2023-01-01 00:21:19
# ..    ...       ...                  ...                   ...
# 95     95         2  2023-01-01 00:20:38   2023-01-01 00:21:26
# 96     96         2  2023-01-01 00:09:16   2023-01-01 00:30:17
# 97     97         2  2023-01-01 00:46:56   2023-01-01 00:59:16
# 98     98         2  2023-01-01 00:10:50   2023-01-01 00:20:19
# 99     99         2  2023-01-01 00:27:35   2023-01-01 00:37:49
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               1.0           0.97         1.0                  N
# 1               1.0           1.10         1.0                  N
# ...
